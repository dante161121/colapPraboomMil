# %% [markdown]
# <a href="https://colab.research.google.com/github/dante161121/colapPraboomMil/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (1.6.0)

# %% [markdown]
# Instala la librería nest_asyncio

# %%
import nest_asyncio, asyncio, json, websockets
import pandas as pd

nest_asyncio.apply()

APP_ID = 127820
TOKEN = "EkjypVRBbLlJhFA"

# buffer global donde se guardan los ticks
ticks_buffer = []

async def connect_and_stream(symbol="BOOM1000", n_ticks=50, timeout=10):
    url = f"wss://ws.derivws.com/websockets/v3?app_id={APP_ID}"
    print("Conectando a:", url)

    async with websockets.connect(url, ping_interval=None, close_timeout=timeout) as ws:
        # 1) Autorizar
        auth_req = {"authorize": TOKEN}
        print("Enviando authorize:", auth_req)
        await ws.send(json.dumps(auth_req))

        auth_resp = json.loads(await ws.recv())
        print("Auth msg_type:", auth_resp.get("msg_type"))
        if auth_resp.get("error"):
            print("ERROR en authorize:", auth_resp["error"])
            return
        print("Autorizado. Login ID:", auth_resp["authorize"]["loginid"])

        # 2) Suscribirse a ticks
        sub_req = {"ticks": symbol, "subscribe": 1}
        print("Enviando suscripción:", sub_req)
        await ws.send(json.dumps(sub_req))

        # 3) Leer n_ticks mensajes y guardarlos en ticks_buffer
        for i in range(n_ticks):
            print(f"Esperando tick {i+1}...")
            msg_raw = await asyncio.wait_for(ws.recv(), timeout=timeout)
            msg = json.loads(msg_raw)

            if msg.get("msg_type") == "tick":
                tick = msg["tick"]
                row = {
                    "symbol": tick["symbol"],
                    "epoch": tick["epoch"],
                    "quote": tick["quote"]
                }
                ticks_buffer.append(row)
                print(f"{i+1} | {row}")
            else:
                print(f"Mensaje {i+1} (no tick):", msg.get("msg_type"))

# Ejecutar: recoge 200 ticks de BOOM1000
asyncio.run(connect_and_stream(symbol="BOOM1000", n_ticks=200, timeout=10))
# Out:
# Conectando a: wss://ws.derivws.com/websockets/v3?app_id=127820
# Enviando authorize: {'authorize': 'EkjypVRBbLlJhFA'}
# Auth msg_type: authorize
# Autorizado. Login ID: VRTC4588120
# Enviando suscripción: {'ticks': 'BOOM1000', 'subscribe': 1}
# Esperando tick 1...
# 1 | {'symbol': 'BOOM1000', 'epoch': 1771693231, 'quote': 14619.286}
# Esperando tick 2...
# 2 | {'symbol': 'BOOM1000', 'epoch': 1771693232, 'quote': 14619.279}
# Esperando tick 3...
# 3 | {'symbol': 'BOOM1000', 'epoch': 1771693233, 'quote': 14619.256}
# Esperando tick 4...
# 4 | {'symbol': 'BOOM1000', 'epoch': 1771693234, 'quote': 14619.242}
# Esperando tick 5...
# 5 | {'symbol': 'BOOM1000', 'epoch': 1771693235, 'quote': 14619.218}
# Esperando tick 6...
# 6 | {'symbol': 'BOOM1000', 'epoch': 1771693236, 'quote': 14619.193}
# Esperando tick 7...
# 7 | {'symbol': 'BOOM1000', 'epoch': 1771693237, 'quote': 14619.181}
# Esperando tick 8...
# 8 | {'symbol': 'BOOM1000', 'epoch': 1771693238, 'quote': 14619.169}
# Esperando tick 9...
# 9 | {'symbol': 'BOOM1000', 'epoch': 1771693239, 'quote': 14619.148}
# Esperando tick 10...
# 10 | {'symbol': 'BOOM1000', 'epoch': 1771693240, 'quote': 14619.143}
# Esperando tick 11...
# 11 | {'symbol': 'BOOM1000', 'epoch': 1771693241, 'quote': 14619.125}
# Esperando tick 12...
# 12 | {'symbol': 'BOOM1000', 'epoch': 1771693242, 'quote': 14619.118}
# Esperando tick 13...
# 13 | {'symbol': 'BOOM1000', 'epoch': 1771693243, 'quote': 14619.114}
# Esperando tick 14...
# 14 | {'symbol': 'BOOM1000', 'epoch': 1771693244, 'quote': 14619.107}
# Esperando tick 15...
# 15 | {'symbol': 'BOOM1000', 'epoch': 1771693245, 'quote': 14619.089}
# Esperando tick 16...
# 16 | {'symbol': 'BOOM1000', 'epoch': 1771693246, 'quote': 14619.077}
# Esperando tick 17...
# 17 | {'symbol': 'BOOM1000', 'epoch': 1771693247, 'quote': 14619.063}
# Esperando tick 18...
# 18 | {'symbol': 'BOOM1000', 'epoch': 1771693248, 'quote': 14619.05}
# Esperando tick 19...
# 19 | {'symbol': 'BOOM1000', 'epoch': 1771693249, 'quote': 14619.017}
# Esperando tick 20...
# 20 | {'symbol': 'BOOM1000', 'epoch': 1771693250, 'quote': 14619.002}
# Esperando tick 21...
# 21 | {'symbol': 'BOOM1000', 'epoch': 1771693251, 'quote': 14618.985}
# Esperando tick 22...
# 22 | {'symbol': 'BOOM1000', 'epoch': 1771693252, 'quote': 14618.972}
# Esperando tick 23...
# 23 | {'symbol': 'BOOM1000', 'epoch': 1771693253, 'quote': 14618.958}
# Esperando tick 24...
# 24 | {'symbol': 'BOOM1000', 'epoch': 1771693254, 'quote': 14618.946}
# Esperando tick 25...
# 25 | {'symbol': 'BOOM1000', 'epoch': 1771693255, 'quote': 14618.944}
# Esperando tick 26...
# 26 | {'symbol': 'BOOM1000', 'epoch': 1771693256, 'quote': 14618.937}
# Esperando tick 27...
# 27 | {'symbol': 'BOOM1000', 'epoch': 1771693257, 'quote': 14618.933}
# Esperando tick 28...
# 28 | {'symbol': 'BOOM1000', 'epoch': 1771693258, 'quote': 14618.927}
# Esperando tick 29...
# 29 | {'symbol': 'BOOM1000', 'epoch': 1771693259, 'quote': 14618.921}
# Esperando tick 30...
# 30 | {'symbol': 'BOOM1000', 'epoch': 1771693260, 'quote': 14618.904}
# Esperando tick 31...
# 31 | {'symbol': 'BOOM1000', 'epoch': 1771693261, 'quote': 14618.899}
# Esperando tick 32...
# 32 | {'symbol': 'BOOM1000', 'epoch': 1771693262, 'quote': 14618.876}
# Esperando tick 33...
# 33 | {'symbol': 'BOOM1000', 'epoch': 1771693263, 'quote': 14618.869}
# Esperando tick 34...
# 34 | {'symbol': 'BOOM1000', 'epoch': 1771693264, 'quote': 14618.86}
# Esperando tick 35...
# 35 | {'symbol': 'BOOM1000', 'epoch': 1771693265, 'quote': 14618.844}
# Esperando tick 36...
# 36 | {'symbol': 'BOOM1000', 'epoch': 1771693266, 'quote': 14618.826}
# Esperando tick 37...
# 37 | {'symbol': 'BOOM1000', 'epoch': 1771693267, 'quote': 14618.815}
# Esperando tick 38...
# 38 | {'symbol': 'BOOM1000', 'epoch': 1771693268, 'quote': 14618.8}
# Esperando tick 39...
# 39 | {'symbol': 'BOOM1000', 'epoch': 1771693269, 'quote': 14618.758}
# Esperando tick 40...
# 40 | {'symbol': 'BOOM1000', 'epoch': 1771693270, 'quote': 14618.755}
# Esperando tick 41...
# 41 | {'symbol': 'BOOM1000', 'epoch': 1771693271, 'quote': 14618.752}
# Esperando tick 42...
# 42 | {'symbol': 'BOOM1000', 'epoch': 1771693272, 'quote': 14618.741}
# Esperando tick 43...
# 43 | {'symbol': 'BOOM1000', 'epoch': 1771693273, 'quote': 14618.703}
# Esperando tick 44...
# 44 | {'symbol': 'BOOM1000', 'epoch': 1771693274, 'quote': 14618.696}
# Esperando tick 45...
# 45 | {'symbol': 'BOOM1000', 'epoch': 1771693275, 'quote': 14618.684}
# Esperando tick 46...
# 46 | {'symbol': 'BOOM1000', 'epoch': 1771693276, 'quote': 14618.658}
# Esperando tick 47...
# 47 | {'symbol': 'BOOM1000', 'epoch': 1771693277, 'quote': 14618.65}
# Esperando tick 48...
# 48 | {'symbol': 'BOOM1000', 'epoch': 1771693278, 'quote': 14618.646}
# Esperando tick 49...
# 49 | {'symbol': 'BOOM1000', 'epoch': 1771693279, 'quote': 14618.642}
# Esperando tick 50...
# 50 | {'symbol': 'BOOM1000', 'epoch': 1771693280, 'quote': 14618.615}
# Esperando tick 51...
# 51 | {'symbol': 'BOOM1000', 'epoch': 1771693281, 'quote': 14618.612}
# Esperando tick 52...
# 52 | {'symbol': 'BOOM1000', 'epoch': 1771693282, 'quote': 14618.609}
# Esperando tick 53...
# 53 | {'symbol': 'BOOM1000', 'epoch': 1771693283, 'quote': 14618.586}
# Esperando tick 54...
# 54 | {'symbol': 'BOOM1000', 'epoch': 1771693284, 'quote': 14618.584}
# Esperando tick 55...
# 55 | {'symbol': 'BOOM1000', 'epoch': 1771693285, 'quote': 14618.562}
# Esperando tick 56...
# 56 | {'symbol': 'BOOM1000', 'epoch': 1771693286, 'quote': 14618.538}
# Esperando tick 57...
# 57 | {'symbol': 'BOOM1000', 'epoch': 1771693287, 'quote': 14618.529}
# Esperando tick 58...
# 58 | {'symbol': 'BOOM1000', 'epoch': 1771693288, 'quote': 14618.51}
# Esperando tick 59...
# 59 | {'symbol': 'BOOM1000', 'epoch': 1771693289, 'quote': 14618.509}
# Esperando tick 60...
# 60 | {'symbol': 'BOOM1000', 'epoch': 1771693290, 'quote': 14618.487}
# Esperando tick 61...
# 61 | {'symbol': 'BOOM1000', 'epoch': 1771693291, 'quote': 14618.468}
# Esperando tick 62...
# 62 | {'symbol': 'BOOM1000', 'epoch': 1771693292, 'quote': 14618.467}
# Esperando tick 63...
# 63 | {'symbol': 'BOOM1000', 'epoch': 1771693293, 'quote': 14618.465}
# Esperando tick 64...
# 64 | {'symbol': 'BOOM1000', 'epoch': 1771693294, 'quote': 14618.433}
# Esperando tick 65...
# 65 | {'symbol': 'BOOM1000', 'epoch': 1771693295, 'quote': 14618.425}
# Esperando tick 66...
# 66 | {'symbol': 'BOOM1000', 'epoch': 1771693296, 'quote': 14618.414}
# Esperando tick 67...
# 67 | {'symbol': 'BOOM1000', 'epoch': 1771693297, 'quote': 14618.397}
# Esperando tick 68...
# 68 | {'symbol': 'BOOM1000', 'epoch': 1771693298, 'quote': 14618.37}
# Esperando tick 69...
# 69 | {'symbol': 'BOOM1000', 'epoch': 1771693299, 'quote': 14618.367}
# Esperando tick 70...
# 70 | {'symbol': 'BOOM1000', 'epoch': 1771693300, 'quote': 14618.322}
# Esperando tick 71...
# 71 | {'symbol': 'BOOM1000', 'epoch': 1771693301, 'quote': 14618.291}
# Esperando tick 72...
# 72 | {'symbol': 'BOOM1000', 'epoch': 1771693302, 'quote': 14618.289}
# Esperando tick 73...
# 73 | {'symbol': 'BOOM1000', 'epoch': 1771693303, 'quote': 14618.271}
# Esperando tick 74...
# 74 | {'symbol': 'BOOM1000', 'epoch': 1771693304, 'quote': 14618.238}
# Esperando tick 75...
# 75 | {'symbol': 'BOOM1000', 'epoch': 1771693305, 'quote': 14618.216}
# Esperando tick 76...
# 76 | {'symbol': 'BOOM1000', 'epoch': 1771693306, 'quote': 14618.214}
# Esperando tick 77...
# 77 | {'symbol': 'BOOM1000', 'epoch': 1771693307, 'quote': 14618.207}
# Esperando tick 78...
# 78 | {'symbol': 'BOOM1000', 'epoch': 1771693308, 'quote': 14618.206}
# Esperando tick 79...
# 79 | {'symbol': 'BOOM1000', 'epoch': 1771693309, 'quote': 14618.198}
# Esperando tick 80...
# 80 | {'symbol': 'BOOM1000', 'epoch': 1771693310, 'quote': 14618.17}
# Esperando tick 81...
# 81 | {'symbol': 'BOOM1000', 'epoch': 1771693311, 'quote': 14618.157}
# Esperando tick 82...
# 82 | {'symbol': 'BOOM1000', 'epoch': 1771693312, 'quote': 14618.138}
# Esperando tick 83...
# 83 | {'symbol': 'BOOM1000', 'epoch': 1771693313, 'quote': 14618.124}
# Esperando tick 84...
# 84 | {'symbol': 'BOOM1000', 'epoch': 1771693314, 'quote': 14618.096}
# Esperando tick 85...
# 85 | {'symbol': 'BOOM1000', 'epoch': 1771693315, 'quote': 14618.089}
# Esperando tick 86...
# 86 | {'symbol': 'BOOM1000', 'epoch': 1771693316, 'quote': 14618.048}
# Esperando tick 87...
# 87 | {'symbol': 'BOOM1000', 'epoch': 1771693317, 'quote': 14618.039}
# Esperando tick 88...
# 88 | {'symbol': 'BOOM1000', 'epoch': 1771693318, 'quote': 14618.025}
# Esperando tick 89...
# 89 | {'symbol': 'BOOM1000', 'epoch': 1771693319, 'quote': 14618.001}
# Esperando tick 90...
# 90 | {'symbol': 'BOOM1000', 'epoch': 1771693320, 'quote': 14618.001}
# Esperando tick 91...
# 91 | {'symbol': 'BOOM1000', 'epoch': 1771693321, 'quote': 14617.983}
# Esperando tick 92...
# 92 | {'symbol': 'BOOM1000', 'epoch': 1771693322, 'quote': 14617.962}
# Esperando tick 93...
# 93 | {'symbol': 'BOOM1000', 'epoch': 1771693323, 'quote': 14617.958}
# Esperando tick 94...
# 94 | {'symbol': 'BOOM1000', 'epoch': 1771693324, 'quote': 14617.949}
# Esperando tick 95...
# 95 | {'symbol': 'BOOM1000', 'epoch': 1771693325, 'quote': 14617.932}
# Esperando tick 96...
# 96 | {'symbol': 'BOOM1000', 'epoch': 1771693326, 'quote': 14617.913}
# Esperando tick 97...
# 97 | {'symbol': 'BOOM1000', 'epoch': 1771693327, 'quote': 14617.907}
# Esperando tick 98...
# 98 | {'symbol': 'BOOM1000', 'epoch': 1771693328, 'quote': 14617.881}
# Esperando tick 99...
# 99 | {'symbol': 'BOOM1000', 'epoch': 1771693329, 'quote': 14617.871}
# Esperando tick 100...
# 100 | {'symbol': 'BOOM1000', 'epoch': 1771693330, 'quote': 14617.848}
# Esperando tick 101...
# 101 | {'symbol': 'BOOM1000', 'epoch': 1771693331, 'quote': 14617.834}
# Esperando tick 102...
# 102 | {'symbol': 'BOOM1000', 'epoch': 1771693332, 'quote': 14617.832}
# Esperando tick 103...
# 103 | {'symbol': 'BOOM1000', 'epoch': 1771693333, 'quote': 14617.828}
# Esperando tick 104...
# 104 | {'symbol': 'BOOM1000', 'epoch': 1771693334, 'quote': 14617.818}
# Esperando tick 105...
# 105 | {'symbol': 'BOOM1000', 'epoch': 1771693335, 'quote': 14617.817}
# Esperando tick 106...
# 106 | {'symbol': 'BOOM1000', 'epoch': 1771693336, 'quote': 14617.806}
# Esperando tick 107...
# 107 | {'symbol': 'BOOM1000', 'epoch': 1771693337, 'quote': 14617.802}
# Esperando tick 108...
# 108 | {'symbol': 'BOOM1000', 'epoch': 1771693338, 'quote': 14617.782}
# Esperando tick 109...
# 109 | {'symbol': 'BOOM1000', 'epoch': 1771693339, 'quote': 14617.748}
# Esperando tick 110...
# 110 | {'symbol': 'BOOM1000', 'epoch': 1771693340, 'quote': 14617.741}
# Esperando tick 111...
# 111 | {'symbol': 'BOOM1000', 'epoch': 1771693341, 'quote': 14617.711}
# Esperando tick 112...
# 112 | {'symbol': 'BOOM1000', 'epoch': 1771693342, 'quote': 14617.703}
# Esperando tick 113...
# 113 | {'symbol': 'BOOM1000', 'epoch': 1771693343, 'quote': 14617.681}
# Esperando tick 114...
# 114 | {'symbol': 'BOOM1000', 'epoch': 1771693344, 'quote': 14617.663}
# Esperando tick 115...
# 115 | {'symbol': 'BOOM1000', 'epoch': 1771693345, 'quote': 14617.638}
# Esperando tick 116...
# 116 | {'symbol': 'BOOM1000', 'epoch': 1771693346, 'quote': 14617.606}
# Esperando tick 117...
# 117 | {'symbol': 'BOOM1000', 'epoch': 1771693347, 'quote': 14617.586}
# Esperando tick 118...
# 118 | {'symbol': 'BOOM1000', 'epoch': 1771693348, 'quote': 14617.556}
# Esperando tick 119...
# 119 | {'symbol': 'BOOM1000', 'epoch': 1771693349, 'quote': 14617.526}
# Esperando tick 120...
# 120 | {'symbol': 'BOOM1000', 'epoch': 1771693350, 'quote': 14617.498}
# Esperando tick 121...
# 121 | {'symbol': 'BOOM1000', 'epoch': 1771693351, 'quote': 14617.487}
# Esperando tick 122...
# 122 | {'symbol': 'BOOM1000', 'epoch': 1771693352, 'quote': 14617.463}
# Esperando tick 123...
# 123 | {'symbol': 'BOOM1000', 'epoch': 1771693353, 'quote': 14617.457}
# Esperando tick 124...
# 124 | {'symbol': 'BOOM1000', 'epoch': 1771693354, 'quote': 14617.423}
# Esperando tick 125...
# 125 | {'symbol': 'BOOM1000', 'epoch': 1771693355, 'quote': 14617.422}
# Esperando tick 126...
# 126 | {'symbol': 'BOOM1000', 'epoch': 1771693356, 'quote': 14617.404}
# Esperando tick 127...
# 127 | {'symbol': 'BOOM1000', 'epoch': 1771693357, 'quote': 14617.373}
# Esperando tick 128...
# 128 | {'symbol': 'BOOM1000', 'epoch': 1771693358, 'quote': 14617.357}
# Esperando tick 129...
# 129 | {'symbol': 'BOOM1000', 'epoch': 1771693359, 'quote': 14617.338}
# Esperando tick 130...
# 130 | {'symbol': 'BOOM1000', 'epoch': 1771693360, 'quote': 14617.32}
# Esperando tick 131...
# 131 | {'symbol': 'BOOM1000', 'epoch': 1771693361, 'quote': 14617.317}
# Esperando tick 132...
# 132 | {'symbol': 'BOOM1000', 'epoch': 1771693362, 'quote': 14617.298}
# Esperando tick 133...
# 133 | {'symbol': 'BOOM1000', 'epoch': 1771693363, 'quote': 14617.297}
# Esperando tick 134...
# 134 | {'symbol': 'BOOM1000', 'epoch': 1771693364, 'quote': 14617.274}
# Esperando tick 135...
# 135 | {'symbol': 'BOOM1000', 'epoch': 1771693365, 'quote': 14617.264}
# Esperando tick 136...
# 136 | {'symbol': 'BOOM1000', 'epoch': 1771693366, 'quote': 14617.25}
# Esperando tick 137...
# 137 | {'symbol': 'BOOM1000', 'epoch': 1771693367, 'quote': 14617.234}
# Esperando tick 138...
# 138 | {'symbol': 'BOOM1000', 'epoch': 1771693368, 'quote': 14617.209}
# Esperando tick 139...
# 139 | {'symbol': 'BOOM1000', 'epoch': 1771693369, 'quote': 14617.207}
# Esperando tick 140...
# 140 | {'symbol': 'BOOM1000', 'epoch': 1771693370, 'quote': 14617.192}
# Esperando tick 141...
# 141 | {'symbol': 'BOOM1000', 'epoch': 1771693371, 'quote': 14617.161}
# Esperando tick 142...
# 142 | {'symbol': 'BOOM1000', 'epoch': 1771693372, 'quote': 14617.143}
# Esperando tick 143...
# 143 | {'symbol': 'BOOM1000', 'epoch': 1771693373, 'quote': 14617.138}
# Esperando tick 144...
# 144 | {'symbol': 'BOOM1000', 'epoch': 1771693374, 'quote': 14617.126}
# Esperando tick 145...
# 145 | {'symbol': 'BOOM1000', 'epoch': 1771693375, 'quote': 14617.121}
# Esperando tick 146...
# 146 | {'symbol': 'BOOM1000', 'epoch': 1771693376, 'quote': 14617.103}
# Esperando tick 147...
# 147 | {'symbol': 'BOOM1000', 'epoch': 1771693377, 'quote': 14617.08}
# Esperando tick 148...
# 148 | {'symbol': 'BOOM1000', 'epoch': 1771693378, 'quote': 14617.068}
# Esperando tick 149...
# 149 | {'symbol': 'BOOM1000', 'epoch': 1771693379, 'quote': 14617.049}
# Esperando tick 150...
# 150 | {'symbol': 'BOOM1000', 'epoch': 1771693380, 'quote': 14617.022}
# Esperando tick 151...
# 151 | {'symbol': 'BOOM1000', 'epoch': 1771693381, 'quote': 14616.998}
# Esperando tick 152...
# 152 | {'symbol': 'BOOM1000', 'epoch': 1771693382, 'quote': 14616.984}
# Esperando tick 153...
# 153 | {'symbol': 'BOOM1000', 'epoch': 1771693383, 'quote': 14616.975}
# Esperando tick 154...
# 154 | {'symbol': 'BOOM1000', 'epoch': 1771693384, 'quote': 14616.959}
# Esperando tick 155...
# 155 | {'symbol': 'BOOM1000', 'epoch': 1771693385, 'quote': 14616.946}
# Esperando tick 156...
# 156 | {'symbol': 'BOOM1000', 'epoch': 1771693386, 'quote': 14616.941}
# Esperando tick 157...
# 157 | {'symbol': 'BOOM1000', 'epoch': 1771693387, 'quote': 14616.91}
# Esperando tick 158...
# 158 | {'symbol': 'BOOM1000', 'epoch': 1771693388, 'quote': 14616.878}
# Esperando tick 159...
# 159 | {'symbol': 'BOOM1000', 'epoch': 1771693389, 'quote': 14616.852}
# Esperando tick 160...
# 160 | {'symbol': 'BOOM1000', 'epoch': 1771693390, 'quote': 14616.817}
# Esperando tick 161...
# 161 | {'symbol': 'BOOM1000', 'epoch': 1771693391, 'quote': 14616.791}
# Esperando tick 162...
# 162 | {'symbol': 'BOOM1000', 'epoch': 1771693392, 'quote': 14616.788}
# Esperando tick 163...
# 163 | {'symbol': 'BOOM1000', 'epoch': 1771693393, 'quote': 14616.787}
# Esperando tick 164...
# 164 | {'symbol': 'BOOM1000', 'epoch': 1771693394, 'quote': 14616.758}
# Esperando tick 165...
# 165 | {'symbol': 'BOOM1000', 'epoch': 1771693395, 'quote': 14616.747}
# Esperando tick 166...
# 166 | {'symbol': 'BOOM1000', 'epoch': 1771693396, 'quote': 14616.746}
# Esperando tick 167...
# 167 | {'symbol': 'BOOM1000', 'epoch': 1771693397, 'quote': 14616.742}
# Esperando tick 168...
# 168 | {'symbol': 'BOOM1000', 'epoch': 1771693398, 'quote': 14616.738}
# Esperando tick 169...
# 169 | {'symbol': 'BOOM1000', 'epoch': 1771693399, 'quote': 14616.73}
# Esperando tick 170...
# 170 | {'symbol': 'BOOM1000', 'epoch': 1771693400, 'quote': 14616.722}
# Esperando tick 171...
# 171 | {'symbol': 'BOOM1000', 'epoch': 1771693401, 'quote': 14616.71}
# Esperando tick 172...
# 172 | {'symbol': 'BOOM1000', 'epoch': 1771693402, 'quote': 14616.669}
# Esperando tick 173...
# 173 | {'symbol': 'BOOM1000', 'epoch': 1771693403, 'quote': 14616.663}
# Esperando tick 174...
# 174 | {'symbol': 'BOOM1000', 'epoch': 1771693404, 'quote': 14616.644}
# Esperando tick 175...
# 175 | {'symbol': 'BOOM1000', 'epoch': 1771693405, 'quote': 14616.642}
# Esperando tick 176...
# 176 | {'symbol': 'BOOM1000', 'epoch': 1771693406, 'quote': 14616.617}
# Esperando tick 177...
# 177 | {'symbol': 'BOOM1000', 'epoch': 1771693407, 'quote': 14616.614}
# Esperando tick 178...
# 178 | {'symbol': 'BOOM1000', 'epoch': 1771693408, 'quote': 14616.605}
# Esperando tick 179...
# 179 | {'symbol': 'BOOM1000', 'epoch': 1771693409, 'quote': 14616.582}
# Esperando tick 180...
# 180 | {'symbol': 'BOOM1000', 'epoch': 1771693410, 'quote': 14616.553}
# Esperando tick 181...
# 181 | {'symbol': 'BOOM1000', 'epoch': 1771693411, 'quote': 14616.535}
# Esperando tick 182...
# 182 | {'symbol': 'BOOM1000', 'epoch': 1771693412, 'quote': 14616.507}
# Esperando tick 183...
# 183 | {'symbol': 'BOOM1000', 'epoch': 1771693413, 'quote': 14616.495}
# Esperando tick 184...
# 184 | {'symbol': 'BOOM1000', 'epoch': 1771693414, 'quote': 14616.491}
# Esperando tick 185...
# 185 | {'symbol': 'BOOM1000', 'epoch': 1771693415, 'quote': 14616.473}
# Esperando tick 186...
# 186 | {'symbol': 'BOOM1000', 'epoch': 1771693416, 'quote': 14616.459}
# Esperando tick 187...
# 187 | {'symbol': 'BOOM1000', 'epoch': 1771693417, 'quote': 14616.437}
# Esperando tick 188...
# 188 | {'symbol': 'BOOM1000', 'epoch': 1771693418, 'quote': 14616.436}
# Esperando tick 189...
# 189 | {'symbol': 'BOOM1000', 'epoch': 1771693419, 'quote': 14616.396}
# Esperando tick 190...
# 190 | {'symbol': 'BOOM1000', 'epoch': 1771693420, 'quote': 14616.384}
# Esperando tick 191...
# 191 | {'symbol': 'BOOM1000', 'epoch': 1771693421, 'quote': 14616.364}
# Esperando tick 192...
# 192 | {'symbol': 'BOOM1000', 'epoch': 1771693422, 'quote': 14616.355}
# Esperando tick 193...
# 193 | {'symbol': 'BOOM1000', 'epoch': 1771693423, 'quote': 14616.306}
# Esperando tick 194...
# 194 | {'symbol': 'BOOM1000', 'epoch': 1771693424, 'quote': 14616.293}
# Esperando tick 195...
# 195 | {'symbol': 'BOOM1000', 'epoch': 1771693425, 'quote': 14616.278}
# Esperando tick 196...
# 196 | {'symbol': 'BOOM1000', 'epoch': 1771693426, 'quote': 14616.266}
# Esperando tick 197...
# 197 | {'symbol': 'BOOM1000', 'epoch': 1771693427, 'quote': 14616.246}
# Esperando tick 198...
# 198 | {'symbol': 'BOOM1000', 'epoch': 1771693428, 'quote': 14616.245}
# Esperando tick 199...
# 199 | {'symbol': 'BOOM1000', 'epoch': 1771693429, 'quote': 14616.219}
# Esperando tick 200...
# 200 | {'symbol': 'BOOM1000', 'epoch': 1771693430, 'quote': 14616.2}

# %% [markdown]
# para recoger 200 ticks y dejarlos almacenados en ticks_buffer

# %%
df = pd.DataFrame(ticks_buffer)
df["datetime"] = pd.to_datetime(df["epoch"], unit="s")
df.set_index("datetime", inplace=True)
df.head()
# Out:
#                        symbol       epoch      quote
# datetime
# 2026-02-21 17:00:31  BOOM1000  1771693231  14619.286
# 2026-02-21 17:00:32  BOOM1000  1771693232  14619.279
# 2026-02-21 17:00:33  BOOM1000  1771693233  14619.256
# 2026-02-21 17:00:34  BOOM1000  1771693234  14619.242
# 2026-02-21 17:00:35  BOOM1000  1771693235  14619.218

# %% [markdown]
# Bloque 2 – Construir el DataFrame base

# %%
import numpy as np

# 1) Retorno logarítmico por tick
df["ret_log"] = np.log(df["quote"]).diff()

# 2) Volatilidad rolling (filtro de volatilidad)
df["vol_50"] = df["ret_log"].rolling(50).std()

# 3) Medias móviles sobre ticks (tendencia)
df["ma_20"] = df["quote"].rolling(20).mean()
df["ma_50"] = df["quote"].rolling(50).mean()

# 4) Señal de cruce de medias (trend-following básico)
df["signal_ma"] = np.where(df["ma_20"] > df["ma_50"], 1, -1)

# 5) Sesión intradía (para trend-following por sesión)
# Suponiendo hora UTC; ajusta si hace falta
hour = df.index.hour
df["session"] = np.select(
    [
        (hour >= 0) & (hour < 8),   # Asia
        (hour >= 8) & (hour < 16),  # Europa
        (hour >= 16) & (hour < 24)  # América
    ],
    ["asia", "europa", "america"],
    default="otro"
)

# 6) Detección simple de spikes (para probabilidad de spike y mean reversion)
# Umbral de spike -> ajusta este número según tus datos
spike_threshold = df["quote"].diff().quantile(0.995)
df["is_spike"] = (df["quote"].diff() >= spike_threshold).astype(int)

# 7) Tiempo desde el último spike (modelo de 'spike intensity')
df["ticks_since_spike"] = df["is_spike"].groupby((df["is_spike"] == 1).cumsum()).cumcount()

df.tail()
# Out:
#                        symbol       epoch      quote       ret_log  \
# datetime
# 2026-02-21 17:03:46  BOOM1000  1771693426  14616.266 -8.210028e-07
# 2026-02-21 17:03:47  BOOM1000  1771693427  14616.246 -1.368339e-06
# 2026-02-21 17:03:48  BOOM1000  1771693428  14616.245 -6.841702e-08
# 2026-02-21 17:03:49  BOOM1000  1771693429  14616.219 -1.778844e-06
# 2026-02-21 17:03:50  BOOM1000  1771693430  14616.200 -1.299927e-06
#
#                            vol_50        ma_20        ma_50  signal_ma  \
# datetime
# 2026-02-21 17:03:46  7.878285e-07  14616.44145  14616.67604         -1
# 2026-02-21 17:03:47  7.860850e-07  14616.42305  14616.65936         -1
# 2026-02-21 17:03:48  7.994319e-07  14616.40505  14616.64290         -1
# 2026-02-21 17:03:49  8.044108e-07  14616.38690  14616.62630         -1
# 2026-02-21 17:03:50  7.982322e-07  14616.36925  14616.60986         -1
#
#                      session  is_spike  ticks_since_spike
# datetime
# 2026-02-21 17:03:46  america         0                106
# 2026-02-21 17:03:47  america         0                107
# 2026-02-21 17:03:48  america         0                108
# 2026-02-21 17:03:49  america         0                109
# 2026-02-21 17:03:50  america         0                110

# %% [markdown]
# Bloque 3 – Features cuantitativas básicas

# %% [markdown]
# Construir el DataFrame base

# %%
# Horizonte de predicción: próximos 10 ticks (ajusta a tu gusto)
horizon = 10

# Spike futuro: 1 si hay al menos un spike en los próximos 'horizon' ticks
df["future_spike"] = (
    df["is_spike"]
    .shift(-horizon)
    .rolling(horizon)
    .max()
)

df["future_spike"] = df["future_spike"].fillna(0).astype(int)
df[["is_spike", "future_spike"]].tail()
# Out:
#                      is_spike  future_spike
# datetime
# 2026-02-21 17:03:46         0             0
# 2026-02-21 17:03:47         0             0
# 2026-02-21 17:03:48         0             0
# 2026-02-21 17:03:49         0             0
# 2026-02-21 17:03:50         0             0

# %% [markdown]
# Bloque 4 – Definir objetivo para Random Forest
# Necesitamos decirle al modelo qué queremos predecir. Por ejemplo:
#
# Objetivo: “¿habrá spike en los próximos N ticks?” (clasificación binaria).

# %%
# Codificar la sesión como variables dummy (one-hot)
df_dummies = pd.get_dummies(df, columns=["session"], drop_first=False)

# Expected session dummy columns
expected_session_dummies = ["session_asia", "session_europa", "session_america"]

# Add missing session dummy columns with 0 if they don't exist
for col in expected_session_dummies:
    if col not in df_dummies.columns:
        df_dummies[col] = 0

# Lista de features cuantitativas
feature_cols = [
    "quote",
    "ret_log",
    "vol_50",
    "ma_20",
    "ma_50",
    "signal_ma",
    "is_spike",
    "ticks_since_spike",
    # dummies de sesión:
    "session_asia",
    "session_europa",
    "session_america",
]

# Filtrar solo filas sin NaNs (por rolling)
data = df_dummies.dropna(subset=feature_cols + ["future_spike"]).copy()

X = data[feature_cols]
y = data["future_spike"]

X.head(), y.value_counts()
# Out:
# (                         quote       ret_log        vol_50        ma_20  \
#  datetime
#  2026-02-21 17:01:21  14618.612 -2.052178e-07  6.269759e-07  14618.74010
#  2026-02-21 17:01:22  14618.609 -2.052179e-07  6.320966e-07  14618.72675
#  2026-02-21 17:01:23  14618.586 -1.573338e-06  6.320981e-07  14618.71260
#  2026-02-21 17:01:24  14618.584 -1.368121e-07  6.415987e-07  14618.69880
#  2026-02-21 17:01:25  14618.562 -1.504935e-06  6.386584e-07  14618.68470
#
#                             ma_50  signal_ma  is_spike  ticks_since_spike  \
#  datetime
#  2026-02-21 17:01:21  14618.93438         -1         0                 50
#  2026-02-21 17:01:22  14618.92098         -1         0                 51
#  2026-02-21 17:01:23  14618.90758         -1         0                 52
#  2026-02-21 17:01:24  14618.89442         -1         0                 53
#  2026-02-21 17:01:25  14618.88130         -1         0                 54
#
#                       session_asia  session_europa  session_america
#  datetime
#  2026-02-21 17:01:21             0               0             True
#  2026-02-21 17:01:22             0               0             True
#  2026-02-21 17:01:23             0               0             True
#  2026-02-21 17:01:24             0               0             True
#  2026-02-21 17:01:25             0               0             True  ,
#  future_spike
#  0    140
#  1     10
#  Name: count, dtype: int64)

# %% [markdown]
# Bloque 5 – Preparar dataset para Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# Train / test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, shuffle=False  # respetar orden temporal
)

rf = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)

# Evaluación básica
y_pred = rf.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[45]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        45
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %% [markdown]
# Bloque 6 – Entrenar el modelo Random Forest

# %%
# Probabilidad estimada de spike
# Check if the model was trained on more than one class, specifically if class 1 is known
if 1 in rf.classes_:
    # If class 1 is known, get its probability
    proba_spike = rf.predict_proba(X_test)[:, list(rf.classes_).index(1)]
else:
    # If class 1 was not in the training data (e.g., y_train contained only class 0),
    # then the probability of spike (class 1) should be considered 0.
    proba_spike = np.zeros(len(X_test))

# Crear un DataFrame alineado con X_test
signal_df = data.loc[X_test.index].copy()
signal_df["proba_spike"] = proba_spike

# Ejemplo de regla:
# - Entrar largo sólo si probabilidad de spike es alta
# - Y la media corta está encima de la larga (tendencia a tu favor)
# - Y volatilidad en rango razonable (no demasiado baja)
p_thr = 0.5  # umbral de probabilidad, ajusta
vol_min, vol_max = signal_df["vol_50"].quantile([0.1, 0.9])

signal_df["signal_model"] = 0
signal_df.loc[
    (signal_df["proba_spike"] >= p_thr) &
    (signal_df["ma_20"] > signal_df["ma_50"]) &
    (signal_df["vol_50"].between(vol_min, vol_max)),
    "signal_model"
] = 1

# Retorno logarítmico alineado
signal_df["ret_log"] = df.loc[signal_df.index, "ret_log"]

# Retorno de la estrategia usando la señal del modelo (shift para evitar look-ahead)
signal_df["ret_strategy"] = signal_df["signal_model"].shift(1) * signal_df["ret_log"]

# Curva de equity
signal_df["equity"] = signal_df["ret_strategy"].cumsum().apply(np.exp)

signal_df[["proba_spike", "signal_model", "equity"]].tail()
# Out:
#                      proba_spike  signal_model  equity
# datetime
# 2026-02-21 17:03:46        0.360             0     1.0
# 2026-02-21 17:03:47        0.355             0     1.0
# 2026-02-21 17:03:48        0.430             0     1.0
# 2026-02-21 17:03:49        0.440             0     1.0
# 2026-02-21 17:03:50        0.425             0     1.0

# %% [markdown]
# Bloque 7 – Convertir predicción en estrategia y equity
# Celda 8 (señal del modelo + combinación con medias / filtros)

# %%
# Retornos y estadística básica
ret = signal_df["ret_strategy"].dropna()

mean_ret = ret.mean()
vol_ret = ret.std()
sharpe = mean_ret / vol_ret * np.sqrt(252*24*60*60)  # ajusta si consideras ticks/segundos

max_dd = (signal_df["equity"].cummax() - signal_df["equity"]).max()

print("Retorno medio por tick:", mean_ret)
print("Volatilidad estrategia:", vol_ret)
print("Sharpe aproximado:", sharpe)
print("Max drawdown:", max_dd)
# Out:
# Retorno medio por tick: 0.0
# Volatilidad estrategia: 0.0
# Sharpe aproximado: nan
# Max drawdown: 0.0
# /tmp/ipython-input-191440362.py:6: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe = mean_ret / vol_ret * np.sqrt(252*24*60*60)  # ajusta si consideras ticks/segundos

# %% [markdown]
# Bloque 8 – Estadísticas del modelo / estrategia

# %%
signal_df.to_csv("boom1000_rf_features_signals.csv")
